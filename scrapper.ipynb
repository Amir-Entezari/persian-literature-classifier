# %% [markdown]
# # Poet Poems Scraping from Ganjoor Website
#
# This Python script is designed to scrape poets' poems from the Ganjoor website. It provides a set of functions to extract poems, their excerpts, and related details from the website's pages, and save them into CSV files based on specified criteria.
#
# ## Functionality
#
# The script comprises several functions:
#
# 1. **`get_poem(url)`**: This function extracts a poem from a provided URL of a webpage containing the poem. It parses the HTML content, retrieves the verses, calculates the number of verses and words, and returns the poem text along with these details.
#
# 2. **`get_book_urls(url, prefix="https://ganjoor.net")`**: This function retrieves URLs of books from a given URL. It extracts the URLs from the webpage and appends them with a provided prefix, typically the Ganjoor website URL.
#
# 3. **`get_part_urls(url, prefix="https://ganjoor.net")`**: This function extracts URLs of each poem's full version from a webpage containing a collection of poem excerpts. It appends them with a given prefix to form complete URLs.
#
# 4. **`get_poet(poet_links, directory="./result", number_of_doc_words=700, print_details=False)`**: This main function takes a list of URLs of poet pages, extracts their poems, and saves them in CSV files according to specified criteria. It iterates over the poet links, retrieves the URLs of books written by each poet, then extracts the URLs of poem excerpts from each book. It further utilizes the `get_poem()` function to extract the poems, considering a maximum number of words per document. Finally, it saves the poems into CSV files and returns a list of dictionaries containing details about the processed documents.
#
# ## Usage
#
# To use this script:
# - Provide a list of URLs of poet pages.
# - Specify the directory where the CSV files will be saved.
# - Optionally set the maximum number of words per document and whether to print details during processing.
#
# Example usage:
#
# ```python
# poet_links = [
#         {
#             "name": "attar",
#             "books": [
#                 {
#                     "name": "asrarname",
#                     "url": "https://ganjoor.net/attar/asrarname"
#                 },
#                 {
#                     "name": "",
#                     "url": "https://ganjoor.net/attar/manteghotteyr/naat"
#                 }
#             ]
#         },
#         {
#             "name": "saadi",
#             "books": [
#                 {
#                     "name": "golestan",
#                     "url": "https://ganjoor.net/saadi/golestan"
#                 }
#             ]
#         }
#     ]
# details = get_poet(poet_links, directory="./poems", number_of_doc_words=800, print_details=True)
# print("Details:", details)

# %%
from src.scrape import *

# %%
import pandas as pd

df = pd.read_csv("/home/amir/Documents/university/projects/NLP/IR-Project/persian_authors.csv")

# %%
df['author'].unique()
# Out:
# array(['moulavi', 'attar', 'rahi', 'ferdousi', 'saeb', 'iqbal', 'saadi',
#        'nezami', 'jami', 'eraghi'], dtype=object)

# %%
df['b_name'].unique()
# Out:
# array(['moulavi', 'manteghotteyr', 'rahi', 'ferdousi', 'saeb',
#        'asrar-khodi', 'romooz-bikhodi', 'payam-mashregh', 'saadi',
#        'nezami', 'jami', 'eraghi'], dtype=object)

# %%
poets = [
        {
            "name": "attar",
            "books": [
                {
                    "name": "asrarname",
                    "url": "https://ganjoor.net/attar/asrarname"
                }
            ]
        },
        {
            "name": "moulavi",
            "books": [
                {
                    "name": "shams",
                    "url": "https://ganjoor.net/moulavi/shams"
                }
            ]
        },
        {
            "name": "rahi",
            "books": [
                {
                    "name": "all-books",
                    "url": "https://ganjoor.net/rahi"
                },
            ]
        },
        {
            "name": "ferdousi",
            "books": [
                {
                    "name": "shahname",
                    "url": "https://ganjoor.net/ferdousi/shahname"
                }
            ]
        },
        {
            "name": "saeb",
            "books": [
                {
                    "name": "divan-saeb",
                    "url": "https://ganjoor.net/saeb/divan-saeb"
                }
            ]
        },
        {
            "name": "iqbal",
            "books": [
                {
                    "name": "all-books",
                    "url": "https://ganjoor.net/iqbal"
                }
            ]
        },
        {
            "name": "saadi",
            "books": [
                {
                    "name": "golestan",
                    "url": "https://ganjoor.net/saadi/golestan"
                },
                {
                    "name": "boostan",
                    "url": "https://ganjoor.net/saadi/boostan"
                },
            ]
        },
        {
            "name": "nezami",
            "books": [
                {
                    "name": "5ganj",
                    "url": "https://ganjoor.net/nezami/5ganj"
                }
            ]
        },
        {
            "name": "jami",
            "books": [
                {
                    "name": "divanj",
                    "url": "https://ganjoor.net/jami/divanj"
                },
                {
                    "name": "7ourang",
                    "url": "https://ganjoor.net/jami/7ourang"
                }
            ]
        },
        {
            "name": "eraghi",
            "books": [
                {
                    "name": "divane",
                    "url": "https://ganjoor.net/eraghi/divane"
                },
                {
                    "name": "oshaghname",
                    "url": "https://ganjoor.net/eraghi/oshaghname"
                }
            ]
        },
    ]

# %%
for poet in poets:
    get_poet(poet, directory="datasets/raw", print_details=True)
# Out:
# /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py:44: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 44 of the file /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.content)
# /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py:67: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 67 of the file /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.content)
# /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py:24: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 24 of the file /home/amir/Documents/university/projects/NLP/IR-Project/src/scrape.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(r.content)
# https://ganjoor.net//attar/asrarname/abkhsh1/sh1 : 1890
# https://ganjoor.net//attar/asrarname/abkhsh2/sh1 : 1287
# https://ganjoor.net//attar/asrarname/abkhsh2/sh2 : 1344
# https://ganjoor.net//attar/asrarname/abkhsh3/sh4 : 842
# https://ganjoor.net//attar/asrarname/abkhsh4/sh1 : 1199
# https://ganjoor.net//attar/asrarname/abkhsh5/sh1 : 1339
# https://ganjoor.net//attar/asrarname/abkhsh6/sh5 : 966
# https://ganjoor.net//attar/asrarname/abkhsh6/sh7 : 701
# https://ganjoor.net//attar/asrarname/abkhsh7/sh5 : 839
# https://ganjoor.net//attar/asrarname/abkhsh7/sh7 : 764
# https://ganjoor.net//attar/asrarname/abkhsh7/sh11 : 731
# https://ganjoor.net//attar/asrarname/abkhsh8/sh2 : 1107
# https://ganjoor.net//attar/asrarname/abkhsh9/sh2 : 811
# https://ganjoor.net//attar/asrarname/abkhsh9/sh5 : 795
# https://ganjoor.net//attar/asrarname/abkhsh10/sh3 : 719
# https://ganjoor.net//attar/asrarname/abkhsh10/sh6 : 859
# https://ganjoor.net//attar/asrarname/abkhsh11/sh2 : 776
# https://ganjoor.net//attar/asrarname/abkhsh11/sh5 : 873
# https://ganjoor.net//attar/asrarname/abkhsh11/sh9 : 737
# https://ganjoor.net//attar/asrarname/abkhsh12/sh4 : 793
# https://ganjoor.net//attar/asrarname/abkhsh12/sh6 : 1375
# https://ganjoor.net//attar/asrarname/abkhsh12/sh10 : 754
# https://ganjoor.net//attar/asrarname/abkhsh12/sh13 : 737
# https://ganjoor.net//attar/asrarname/abkhsh13/sh2 : 956
# https://ganjoor.net//attar/asrarname/abkhsh14/sh2 : 966
# https://ganjoor.net//attar/asrarname/abkhsh14/sh5 : 766
# https://ganjoor.net//attar/asrarname/abkhsh15/sh2 : 1269
# https://ganjoor.net//attar/asrarname/abkhsh15/sh5 : 732
# https://ganjoor.net//attar/asrarname/abkhsh16/sh4 : 1281
# https://ganjoor.net//attar/asrarname/abkhsh17/sh3 : 746
# https://ganjoor.net//attar/asrarname/abkhsh18/sh2 : 845
# https://ganjoor.net//moulavi/shams/ghazalsh/sh3 : 848
# https://ganjoor.net//moulavi/shams/ghazalsh/sh7 : 909
# https://ganjoor.net//moulavi/shams/ghazalsh/sh13 : 951
# https://ganjoor.net//moulavi/shams/ghazalsh/sh17 : 852
# https://ganjoor.net//moulavi/shams/ghazalsh/sh21 : 804
# https://ganjoor.net//moulavi/shams/ghazalsh/sh24 : 983
# https://ganjoor.net//moulavi/shams/ghazalsh/sh27 : 1051
# https://ganjoor.net//moulavi/shams/ghazalsh/sh30 : 716
# https://ganjoor.net//moulavi/shams/ghazalsh/sh33 : 824
# https://ganjoor.net//moulavi/shams/ghazalsh/sh38 : 814
# https://ganjoor.net//moulavi/shams/ghazalsh/sh43 : 883
# https://ganjoor.net//moulavi/shams/ghazalsh/sh46 : 800
# https://ganjoor.net//moulavi/shams/ghazalsh/sh51 : 702
# https://ganjoor.net//moulavi/shams/ghazalsh/sh55 : 721
# https://ganjoor.net//moulavi/shams/ghazalsh/sh59 : 741
# https://ganjoor.net//moulavi/shams/ghazalsh/sh64 : 818
# https://ganjoor.net//moulavi/shams/ghazalsh/sh68 : 722
# https://ganjoor.net//moulavi/shams/ghazalsh/sh73 : 822
# https://ganjoor.net//moulavi/shams/ghazalsh/sh78 : 792
# https://ganjoor.net//moulavi/shams/ghazalsh/sh82 : 760
# https://ganjoor.net//moulavi/shams/ghazalsh/sh88 : 783
# https://ganjoor.net//moulavi/shams/ghazalsh/sh94 : 819
# https://ganjoor.net//moulavi/shams/ghazalsh/sh98 : 851
# https://ganjoor.net//moulavi/shams/ghazalsh/sh102 : 810
# https://ganjoor.net//moulavi/shams/ghazalsh/sh109 : 740
# https://ganjoor.net//moulavi/shams/ghazalsh/sh116 : 770
# https://ganjoor.net//moulavi/shams/ghazalsh/sh120 : 718
# https://ganjoor.net//moulavi/shams/ghazalsh/sh125 : 731
# https://ganjoor.net//moulavi/shams/ghazalsh/sh131 : 959
# https://ganjoor.net//moulavi/shams/ghazalsh/sh136 : 794
# https://ganjoor.net//moulavi/shams/ghazalsh/sh141 : 751
# https://ganjoor.net//ferdousi/shahname/aghaz/sh3 : 705
# https://ganjoor.net//ferdousi/shahname/aghaz/sh7 : 835
# https://ganjoor.net//ferdousi/shahname/aghaz/sh12 : 1278
# https://ganjoor.net//ferdousi/shahname/qmars/sh2 : 872
# https://ganjoor.net//ferdousi/shahname/jamshid/sh1 : 873
# https://ganjoor.net//ferdousi/shahname/jamshid/sh3 : 1067
# https://ganjoor.net//ferdousi/shahname/zahak/sh3 : 1225
# https://ganjoor.net//ferdousi/shahname/zahak/sh6 : 883
# https://ganjoor.net//ferdousi/shahname/zahak/sh7 : 958
# https://ganjoor.net//ferdousi/shahname/zahak/sh10 : 900
# https://ganjoor.net//ferdousi/shahname/zahak/sh12 : 1395
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh2 : 1335
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh5 : 820
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh6 : 1276
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh9 : 907
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh11 : 1060
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh13 : 1917
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh15 : 827
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh18 : 731
# https://ganjoor.net//ferdousi/shahname/fereydoon/sh20 : 1380
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh2 : 1948
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh3 : 1469
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh4 : 750
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh6 : 771
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh7 : 971
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh9 : 1031
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh10 : 1245
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh12 : 1082
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh13 : 863
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh14 : 953
# https://ganjoor.net//ferdousi/shahname/manoochehr/sh15 : 1526
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh4 : 794
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh8 : 830
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh12 : 709
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh16 : 754
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh21 : 845
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh26 : 742
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh30 : 729
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh35 : 731
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh39 : 895
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh44 : 787
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh49 : 723
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh56 : 900
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh62 : 710
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh67 : 713
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh72 : 738
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh77 : 731
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh83 : 713
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh89 : 862
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh92 : 876
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh96 : 820
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh101 : 729
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh105 : 714
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh109 : 789
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh114 : 745
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh120 : 778
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh126 : 786
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh131 : 858
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh135 : 730
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh139 : 834
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh143 : 777
# https://ganjoor.net//saeb/divan-saeb/ghazalkasa/sh147 : 729
# https://ganjoor.net//saadi/golestan/gbab1/sh8 : 713
# https://ganjoor.net//saadi/golestan/gbab1/sh17 : 791
# https://ganjoor.net//saadi/golestan/gbab1/sh32 : 713
# https://ganjoor.net//saadi/golestan/gbab2/sh18 : 724
# https://ganjoor.net//saadi/golestan/gbab2/sh31 : 766
# https://ganjoor.net//saadi/golestan/gbab2/sh44 : 736
# https://ganjoor.net//saadi/golestan/gbab3/sh21 : 711
# https://ganjoor.net//saadi/golestan/gbab3/sh27 : 814
# https://ganjoor.net//saadi/golestan/gbab5/sh10 : 724
# https://ganjoor.net//saadi/golestan/gbab5/sh19 : 708
# https://ganjoor.net//saadi/golestan/gbab7/sh17 : 757
# https://ganjoor.net//saadi/golestan/gbab8/sh29 : 703
# https://ganjoor.net//saadi/golestan/gbab8/sh58 : 709
# https://ganjoor.net//saadi/golestan/gbab8/sh88 : 724
# https://ganjoor.net//saadi/boostan/niyayesh/sh1 : 773
# https://ganjoor.net//saadi/boostan/niyayesh/sh4 : 1224
# https://ganjoor.net//saadi/boostan/bab1/sh1 : 1094
# https://ganjoor.net//saadi/boostan/bab1/sh2 : 1636
# https://ganjoor.net//saadi/boostan/bab1/sh6 : 719
# https://ganjoor.net//saadi/boostan/bab1/sh10 : 753
# https://ganjoor.net//saadi/boostan/bab1/sh13 : 711
# https://ganjoor.net//saadi/boostan/bab1/sh16 : 820
# https://ganjoor.net//saadi/boostan/bab1/sh22 : 770
# https://ganjoor.net//saadi/boostan/bab1/sh26 : 761
# https://ganjoor.net//saadi/boostan/bab1/sh28 : 936
# https://ganjoor.net//saadi/boostan/bab1/sh31 : 845
# https://ganjoor.net//saadi/boostan/bab1/sh33 : 744
# https://ganjoor.net//saadi/boostan/bab1/sh39 : 758
# https://ganjoor.net//saadi/boostan/bab2/sh5 : 931
# https://ganjoor.net//saadi/boostan/bab2/sh10 : 889
# https://ganjoor.net//saadi/boostan/bab2/sh15 : 779
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh3 : 1124
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh5 : 927
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh7 : 946
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh9 : 1246
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh10 : 809
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh12 : 974
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh13 : 723
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh15 : 1021
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh18 : 1675
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh20 : 970
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh22 : 702
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh23 : 1593
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh24 : 1006
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh25 : 1792
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh28 : 1115
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh29 : 986
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh30 : 840
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh33 : 867
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh35 : 832
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh36 : 1011
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh38 : 814
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh40 : 1484
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh41 : 2233
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh43 : 1277
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh44 : 785
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh45 : 737
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh46 : 747
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh48 : 1554
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh51 : 1048
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh52 : 2550
# https://ganjoor.net//nezami/5ganj/khosro-shirin/sh53 : 1080
# https://ganjoor.net//jami/7ourang/7-2/sh3 : 728
# https://ganjoor.net//jami/7ourang/7-2/sh7 : 819
# https://ganjoor.net//jami/7ourang/7-2/sh11 : 814
# https://ganjoor.net//jami/7ourang/7-2/sh17 : 922
# https://ganjoor.net//jami/7ourang/7-2/sh22 : 706
# https://ganjoor.net//jami/7ourang/7-2/sh27 : 834
# https://ganjoor.net//jami/7ourang/7-2/sh29 : 734
# https://ganjoor.net//jami/7ourang/7-2/sh33 : 788
# https://ganjoor.net//jami/7ourang/7-2/sh39 : 810
# https://ganjoor.net//jami/7ourang/7-2/sh43 : 705
# https://ganjoor.net//jami/7ourang/7-2/sh48 : 853
# https://ganjoor.net//jami/7ourang/7-2/sh56 : 932
# https://ganjoor.net//jami/7ourang/7-2/sh59 : 727
# https://ganjoor.net//jami/7ourang/7-2/sh64 : 757
# https://ganjoor.net//jami/7ourang/7-2/sh68 : 777
# https://ganjoor.net//jami/7ourang/7-2/sh71 : 714
# https://ganjoor.net//jami/7ourang/7-2/sh73 : 717
# https://ganjoor.net//jami/7ourang/7-3/sh3 : 1348
# https://ganjoor.net//jami/7ourang/7-3/sh6 : 886
# https://ganjoor.net//jami/7ourang/7-3/sh9 : 1102
# https://ganjoor.net//jami/7ourang/7-3/sh12 : 905
# https://ganjoor.net//jami/7ourang/7-3/sh15 : 908
# https://ganjoor.net//jami/7ourang/7-3/sh18 : 965
# https://ganjoor.net//jami/7ourang/7-3/sh20 : 996
# https://ganjoor.net//jami/7ourang/7-3/sh22 : 831
# https://ganjoor.net//jami/7ourang/7-3/sh25 : 749
# https://ganjoor.net//jami/7ourang/7-3/sh28 : 1074
# https://ganjoor.net//jami/7ourang/7-3/sh31 : 768
# https://ganjoor.net//jami/7ourang/7-3/sh34 : 1129
# https://ganjoor.net//jami/7ourang/7-3/sh37 : 793
# https://ganjoor.net//jami/7ourang/7-3/sh40 : 1035
# https://ganjoor.net//eraghi/divane/ghazale/sh7 : 770
# https://ganjoor.net//eraghi/divane/ghazale/sh13 : 745
# https://ganjoor.net//eraghi/divane/ghazale/sh18 : 784
# https://ganjoor.net//eraghi/divane/ghazale/sh23 : 716
# https://ganjoor.net//eraghi/divane/ghazale/sh28 : 737
# https://ganjoor.net//eraghi/divane/ghazale/sh34 : 792
# https://ganjoor.net//eraghi/divane/ghazale/sh40 : 760
# https://ganjoor.net//eraghi/divane/ghazale/sh46 : 720
# https://ganjoor.net//eraghi/divane/ghazale/sh52 : 716
# https://ganjoor.net//eraghi/divane/ghazale/sh58 : 770
# https://ganjoor.net//eraghi/divane/ghazale/sh63 : 718
# https://ganjoor.net//eraghi/divane/ghazale/sh70 : 715
# https://ganjoor.net//eraghi/divane/ghazale/sh76 : 770
# https://ganjoor.net//eraghi/divane/ghazale/sh81 : 770
# https://ganjoor.net//eraghi/divane/ghazale/sh87 : 882
# https://ganjoor.net//eraghi/divane/ghazale/sh93 : 764
# https://ganjoor.net//eraghi/divane/ghazale/sh99 : 733
# https://ganjoor.net//eraghi/divane/ghazale/sh105 : 775
# https://ganjoor.net//eraghi/divane/ghazale/sh110 : 739
# https://ganjoor.net//eraghi/divane/ghazale/sh116 : 706
# https://ganjoor.net//eraghi/divane/ghazale/sh122 : 776
# https://ganjoor.net//eraghi/divane/ghazale/sh126 : 724
# https://ganjoor.net//eraghi/divane/ghazale/sh131 : 721
# https://ganjoor.net//eraghi/divane/ghazale/sh137 : 702
# https://ganjoor.net//eraghi/divane/ghazale/sh143 : 775
# https://ganjoor.net//eraghi/divane/ghazale/sh150 : 836
# https://ganjoor.net//eraghi/divane/ghazale/sh155 : 875
# https://ganjoor.net//eraghi/divane/ghazale/sh162 : 874
# https://ganjoor.net//eraghi/divane/ghazale/sh167 : 836
# https://ganjoor.net//eraghi/divane/ghazale/sh174 : 749
# https://ganjoor.net//eraghi/divane/ghazale/sh179 : 721

# %%
import os

path = '/home/amir/Documents/university/projects/NLP/IR-Project/datasets/raw'
all_files = [os.path.join(path, file) for file in os.listdir(path) if file.endswith('.csv')]

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# Concatenate all dataframes into one
frame = pd.concat(li, axis=0, ignore_index=True)

# Save the merged DataFrame to a new CSV file in the desired location
frame.to_csv('datasets/raw/persian_authors.csv', index=False)
